# %% [markdown]
# ## In this script, we detect bacterial communities that have a particular threshold of AMR genes in common

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from plotly.graph_objs import Scatter3d, Figure

# %%
# Read the rgi results combiined csv
combined_data_tsv = pd.read_csv("../Results/combined_data_tsv.tsv", sep="\t")
# Out:
# /tmp/ipykernel_30090/1188762648.py:2: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_data_tsv = pd.read_csv("../Results/combined_data_tsv.tsv", sep="\t")

# %% [markdown]
# ##### We use only the perfect and strict hits for detecting the bacterial communities

# %%
combined_data_perfect_strict_tsv = combined_data_tsv[combined_data_tsv["Cut_Off"].isin(["Perfect", "Strict"])]

# %%
# Pivot the data
combined_data_perfect_strict_pivoted = combined_data_perfect_strict_tsv.pivot_table(
    index='organism',
    columns='Best_Hit_ARO',
    values='Best_Identities',
    aggfunc='sum'  
)

# Replace NaNs with 0 and round to nearest integer 
combined_data_perfect_strict_pivoted = combined_data_perfect_strict_pivoted.fillna(0)
combined_data_perfect_strict_pivoted = (combined_data_perfect_strict_pivoted / 100).round(0).astype(int)

# Filter out organisms with fewer than 5 total AMR genes
combined_data_perfect_strict_pivoted = combined_data_perfect_strict_pivoted[
    combined_data_perfect_strict_pivoted.sum(axis=1) >= 3 
]

# Drop genes that are absent in all bacteria
combined_data_perfect_strict_pivoted = combined_data_perfect_strict_pivoted.loc[:, (combined_data_perfect_strict_pivoted != 0).any(axis=0)]

# %% [markdown]
# ##### Now we detect and plot the communities

# %%
import pandas as pd
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from plotly.graph_objs import Scatter3d, Figure

# Prepare data
organisms = combined_data_perfect_strict_pivoted.index.tolist()
X = combined_data_perfect_strict_pivoted.values

# Cosine similarity matrix 
cos_sim = cosine_similarity(X)

SIM_THRESHOLD = 0.75
CLIQUE_SIZE_THRESHOLD = 5

# Build graph with edges only if sim ≥ threshold
G = nx.Graph()
G.add_nodes_from(organisms)

n = len(organisms)
for i in range(n):
    for j in range(i + 1, n):
        if cos_sim[i, j] >= SIM_THRESHOLD:
            G.add_edge(organisms[i], organisms[j], weight=cos_sim[i, j])

print(f"Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Find maximal cliques
candidate_cliques = list(nx.find_cliques(G))

# Validate cliques (every pair must satisfy similarity) AND size ≥ 5
def clique_valid(clique, sim_matrix, labels, threshold):
    indices = [labels.index(node) for node in clique]
    for i in range(len(indices)):
        for j in range(i + 1, len(indices)):
            if sim_matrix[indices[i], indices[j]] < threshold:
                return False
    return True

strict_cliques = []
used_nodes = set()


for clique in sorted(candidate_cliques, key=len, reverse=True):
    # Filter by size
    if len(clique) < CLIQUE_SIZE_THRESHOLD:
        continue
    # Filter by internal similarity
    if not clique_valid(clique, cos_sim, organisms, SIM_THRESHOLD):
        continue
    # Ensure no overlap with already used nodes
    if any(node in used_nodes for node in clique):
        continue
    # Accept clique
    strict_cliques.append(clique)
    used_nodes.update(clique)

print(f"✅ Retained {len(strict_cliques)} strict cliques with ≥ {CLIQUE_SIZE_THRESHOLD} members and all pairwise sim ≥ {SIM_THRESHOLD}")

# Assign community index
node_community_map = {}
for idx, clique in enumerate(strict_cliques):
    for node in clique:
        node_community_map[node] = idx

# Remove nodes not in any community
filtered_nodes = list(node_community_map.keys())
G_filtered = G.subgraph(filtered_nodes).copy()

# Color mapping
node_colors = [node_community_map[node] for node in G_filtered.nodes()]
node_text = list(G_filtered.nodes())

# 3D Layout and Visualization
pos = nx.spring_layout(G_filtered, dim=3, seed=42)

node_x = [pos[node][0] for node in G_filtered.nodes()]
node_y = [pos[node][1] for node in G_filtered.nodes()]
node_z = [pos[node][2] for node in G_filtered.nodes()]

# Edges within same community
edge_x, edge_y, edge_z = [], [], []
for u, v in G_filtered.edges():
    if node_community_map[u] == node_community_map[v]:
        x0, y0, z0 = pos[u]
        x1, y1, z1 = pos[v]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]
        edge_z += [z0, z1, None]

# Plotting
edge_trace = Scatter3d(
    x=edge_x, y=edge_y, z=edge_z,
    mode='lines',
    line=dict(width=2, color='gray'),
    hoverinfo='none'
)

node_trace = Scatter3d(
    x=node_x, y=node_y, z=node_z,
    mode='markers',
    marker=dict(
        size=6,
        color=node_colors,
        colorscale='Viridis',
        opacity=0.9,
        colorbar=dict(title="Community Index")
    ),
    text=node_text,
    hoverinfo='text'
)

fig = Figure(data=[edge_trace, node_trace])
fig.update_layout(
    title = f'Bacterial Communities Based on Shared AMR Genes (Each Community ≥ {CLIQUE_SIZE_THRESHOLD} Bacteria, Pairwise Cosine Similarity ≥ {SIM_THRESHOLD})',
    showlegend=False,
    margin=dict(l=0, r=0, b=0, t=50),
    scene=dict(
        xaxis=dict(showgrid=False, zeroline=False),
        yaxis=dict(showgrid=False, zeroline=False),
        zaxis=dict(showgrid=False, zeroline=False)
    )
)

# Save
fig.write_html("../Results/communities.html")
# Out:
# Graph: 1194 nodes, 24289 edges
# ✅ Retained 28 strict cliques with ≥ 5 members and all pairwise sim ≥ 0.75

# %% [markdown]
# #### We iterate through each community, see its members and the frequency of the genes present in it

# %%
print("\n=== Community AMR Gene Profiles ===")

for idx, clique in enumerate(strict_cliques):
    print(f"\n🔹 Community {idx + 1} (Size: {len(clique)})")
    print("Members:")
    for org in clique:
        print(f"   - {org}")

    # Subset AMR gene profile
    community_matrix = combined_data_perfect_strict_pivoted.loc[clique]

    # Compute frequency 
    gene_presence_count = (community_matrix > 0).sum(axis=0)
    gene_presence_freq = gene_presence_count[gene_presence_count > 0].sort_values(ascending=False)

    print("\nTop AMR genes by frequency (count/community size):")
    print(gene_presence_freq/len(clique))

    # Optional: Save each community profile to CSV
    # community_matrix.to_csv(f"../Results/community_{idx + 1}_amr_profile.csv")
# Out:
# === Community AMR Gene Profiles ===
#
# 🔹 Community 1 (Size: 92)
# Members:
#    - Pseudomonas kielensis strain ZE23JCel16
#    - Pseudomonas marincola strain YSy11
#    - Aquipseudomonas alcaligenes strain NEB 585
#    - Agarivorans aestuarii strain KCTC 32543
#    - Pseudomonas qingdaonensis strain S-1
#    - Pseudomonas cavernae strain K2W31S-8
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# Acinetobacter baumannii AbaQ    1.000000
# rsmA                            1.000000
# adeF                            1.000000
# Pseudomonas aeruginosa soxR     0.573770
# FosA8                           0.442623
# ArnT                            0.065574
# Pseudomonas aeruginosa CpxR     0.016393
# OXA-50                          0.016393
# YajC                            0.016393
# vanT gene in vanG cluster       0.016393
# dtype: float64
#
# 🔹 Community 4 (Size: 33)
# Members:
#    - Streptomyces kanamyceticus strain ATCC 12853
#    - Streptomyces microflavus strain NA06532
#    - Streptomyces griseorubiginosus strain 3E-1
#    - Streptomyces janthinus strain JCM 4387
#    - Micromonospora terminaliae strain DSM 101760
#    - Streptomyces cadmiisoli strain ZFG47
#    - Streptomyces chartreusis strain ATCC 14922
#    - Micromonospora zamorensis strain NBC_00407
#    - Micromonospora halotolerans strain DSM 45598
#    - Streptomyces atratus strain SCSIO_ZH16
#    - Streptomyces laculatispora strain Mut2
#    - Streptomyces platensis strain ATCC 23948
#    - Nonomuraea glycinis strain NBC 01726
#    - Streptomyces inhibens strain NRRL30439
#    - Streptomyces fagopyri strain QMT-28
#    - Streptomyces bathyalis strain ASO4wet
#    - Streptomyces tauricus strain NBC_00189
#    - Streptomyces rectiverticillatus strain B15-08
#    - Streptomyces vilmorinianum strain YP1
#    - Streptomyces griseochromogenes strain ATCC 14511
#    - Dactylosporangium fulvum strain NRRL B-16292
#    - Streptomyces mirabilis strain NBC_00379
#    - Streptomyces alboniger strain ATCC 12461
#    - Streptomyces nodosus strain ATCC 14899
#    - Streptomyces scabiei 87.22
#    - Streptomyces ferrugineus strain CCTCC AA2014009
#    - Micromonospora globbae strain NBC_00256
#    - Streptomyces canus strain NBC_00277
#    - Streptomyces cyaneochromogenes strain MK-45
#    - Streptomyces pseudovenezuelae strain NBC_00598
#    - Streptomyces durmitorensis strain MS405
#    - Nocardiopsis gilva YIM 90087
#    - Streptomyces halobius strain 3_2
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# HelR                                                                               1.000000
# Streptomyces rimosus otr(A)                                                        1.000000
# Streptomyces venezuelae rox                                                        1.000000
# Streptomyces lividans otr(A)                                                       0.181818
# Planobispora rosea EF-Tu mutants conferring resistance to inhibitor GE2270A        0.060606
# AAC(6')-Ib-SK                                                                      0.030303
# AAC(3)-VIIa                                                                        0.030303
# Streptomyces cinnamoneus EF-Tu mutants conferring resistance to elfamycin          0.030303
# Nocardia farcinica rox                                                             0.030303
# Mycobacterium tuberculosis rpsL mutations conferring resistance to Streptomycin    0.030303
# mgtA                                                                               0.030303
# dtype: float64
#
# 🔹 Community 5 (Size: 29)
# Members:
#    - Aggregatibacter segnis ATCC 33393 strain NCTC 10977
#    - Haemophilus haemolyticus strain NCTC10839
#    - Aggregatibacter aphrophilus ATCC 33389 strain NCTC 5906
#    - Avibacterium volantium strain NCTC3438
#    - Mannheimia pernigra strain 17CN0883
#    - Aggregatibacter actinomycetemcomitans strain 4S
#    - Bisgaardia hudsonensis strain M327/99/2
#    - Mannheimia succiniciproducens MBEL55E
#    - Actinobacillus delphinicola strain NCTC12871
#    - Gallibacterium salpingitidis strain FC22
#    - Frederiksenia canicola strain HPA 21
#    - Actinobacillus pleuropneumoniae strain S4074
#    - Pasteurella canis strain HL_NV12211
#    - Haemophilus pittmaniae strain NCTC13334
#    - Actinobacillus suis ATCC 33415
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# CRP                             1.000000
# QnrS2                           1.000000
# rsmA                            1.000000
# ALI-1                           0.066667
# adeF                            0.066667
# dfrA6 from Proteus mirabilis    0.066667
# dtype: float64
#
# 🔹 Community 9 (Size: 13)
# Members:
#    - Salmonella bongori NCTC 12419
#    - Citrobacter amalonaticus strain FDAARGOS_1489
#    - Citrobacter farmeri strain FDAARGOS 1423
#    - Citrobacter koseri ATCC BAA-895
#    - Citrobacter werkmanii strain FDAARGOS_616
#    - Citrobacter arsenatis strain LY-1
#    - Citrobacter braakii strain MiY-A
#    - Citrobacter rodentium NBRC 105723 = DSM 16636
#    - Citrobacter europaeus strain WF1643
#    - Citrobacter freundii strain MSB1_1H isolate MSB1_1H
#    - Citrobacter pasteurii strain FDAARGOS 1424
#    - Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
#    - Pseudocitrobacter corydidari isolate G163CM
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# CRP                                                                                                                     1.000000
# Escherichia coli soxS with mutation conferring antibiotic resistance                                                    1.000000
# Klebsiella pneumoniae KpnF                                                                                              1.000000
# Klebsiella pneumoniae KpnE                                                                                              1.000000
# Haemophilus influenzae PBP3 conferring resistance to beta-lactam antibiotics                                            1.000000
# Escherichia coli EF-Tu mutants conferring resistance to Pulvomycin                                                      1.000000
# Escherichia coli acrA                                                                                                   1.000000
# Escherichia coli AcrAB-TolC with MarR mutations conferring resistance to ciprofloxacin and tetracycline                 1.000000
# acrB                                                                                                                    1.000000
# leuO                                                                                                                    1.000000
# marA                                                                                                                    1.000000
# mdtC                                                                                                                    1.000000
# emrB                                                                                                                    1.000000
# bacA                                                                                                                    1.000000
# msbA                                                                                                                    1.000000
# rsmA                                                                                                                    1.000000
# mdtB                                                                                                                    1.000000
# emrR                                                                                                                    1.000000
# kdpE                                                                                                                    1.000000
# Escherichia coli GlpT with mutation conferring resistance to fosfomycin                                                 0.923077
# baeR                                                                                                                    0.923077
# acrD                                                                                                                    0.923077
# cpxA                                                                                                                    0.923077
# emrA                                                                                                                    0.923077
# Escherichia coli UhpT with mutation conferring resistance to fosfomycin                                                 0.923077
# mdtG                                                                                                                    0.846154
# Escherichia coli mdfA                                                                                                   0.846154
# ArnT                                                                                                                    0.846154
# PmrF                                                                                                                    0.846154
# H-NS                                                                                                                    0.769231
# mdtM                                                                                                                    0.769231
# ugd                                                                                                                     0.538462
# Escherichia coli AcrAB-TolC with AcrR mutation conferring resistance to ciprofloxacin, tetracycline, and ceftazidime    0.461538
# Escherichia coli soxR with mutation conferring antibiotic resistance                                                    0.384615
# MdtK                                                                                                                    0.153846
# CFE-1                                                                                                                   0.153846
# oqxB                                                                                                                    0.153846
# golS                                                                                                                    0.153846
# QnrB12                                                                                                                  0.153846
# sdiA                                                                                                                    0.153846
# oqxA                                                                                                                    0.153846
# CMY-70                                                                                                                  0.076923
# AAC(6')-Iaa                                                                                                             0.076923
# AAC(6')-If                                                                                                              0.076923
# CKO-1                                                                                                                   0.076923
# CMY-100                                                                                                                 0.076923
# CMY-132                                                                                                                 0.076923
# CMY-159                                                                                                                 0.076923
# CMY-48                                                                                                                  0.076923
# QnrB19                                                                                                                  0.076923
# OXA-48                                                                                                                  0.076923
# QnrB27                                                                                                                  0.076923
# adeF                                                                                                                    0.076923
# mdsC                                                                                                                    0.076923
# mdsB                                                                                                                    0.076923
# mdsA                                                                                                                    0.076923
# mdtN                                                                                                                    0.076923
# dtype: float64
#
# 🔹 Community 10 (Size: 11)
# Members:
#    - Staphylococcus nepalensis strain JS11
#    - Staphylococcus carnosus strain FDAARGOS_883
#    - Staphylococcus haemolyticus strain ATCC 29970
#    - Staphylococcus debuckii strain SDB 2975
#    - Staphylococcus piscifermentans strain NCTC13836
#    - Staphylococcus muscae strain NCTC13833
#    - Staphylococcus condimenti strain NCTC13827
#    - Staphylococcus simulans strain IVB6189
#    - Staphylococcus gallinarum strain STP534
#    - Staphylococcus hominis strain FDAARGOS_575
#    - Staphylococcus saccharolyticus strain FDAARGOS_1074
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# norC                                                                              1.000000
# sepA                                                                              1.000000
# sdrM                                                                              1.000000
# salD                                                                              0.090909
# Staphylococcus aureus fusE with mutation conferring resistance to fusidic acid    0.090909
# salE                                                                              0.090909
# tet(K)                                                                            0.090909
# dtype: float64
#
# 🔹 Community 11 (Size: 9)
# Members:
#    - Catenulispora acidiphila DSM 44928
#    - Streptomyces xiamenensis strain MCCC 1A01550
#    - Agromyces laixinhei strain HY052
#    - Rathayibacter toxicus strain FH79
#    - Saccharothrix espanaensis DSM 44229
#    - Tomitella fengzijianii strain HY188
#    - Actinoplanes teichomyceticus ATCC 31121
#    - Streptomyces roseirectus strain CRXT-G-22
#    - Tsukamurella paurometabola DSM 20162
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# vanX gene in vanO cluster       1.000000
# vanO                            1.000000
# vanH gene in vanO cluster       1.000000
# Streptomyces venezuelae rox     0.222222
# Streptomyces rimosus otr(A)     0.111111
# Nocardia farcinica rox          0.111111
# Streptomyces lividans otr(A)    0.111111
# dtype: float64
#
# 🔹 Community 12 (Size: 9)
# Members:
#    - Jejubacter calystegiae strain KSNA2
#    - Cronobacter sakazakii strain CS-931
#    - Cronobacter turicensis strain LMG23827
#    - Cronobacter malonaticus LMG 23826
#    - Cronobacter universalis NCTC 9529
#    - Siccibacter colletis strain YSD YN2
#    - Cronobacter dublinensis subsp. dublinensis LMG 23823
#    - Cronobacter muytjensii ATCC 51329
#    - Cronobacter condimenti 1330 strain LMG 26250
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# CRP                                                                                                        1.000000
# Escherichia coli EF-Tu mutants conferring resistance to Pulvomycin                                         1.000000
# Escherichia coli AcrAB-TolC with MarR mutations conferring resistance to ciprofloxacin and tetracycline    1.000000
# marA                                                                                                       1.000000
# msbA                                                                                                       1.000000
# rsmA                                                                                                       1.000000
# emrR                                                                                                       1.000000
# Klebsiella pneumoniae KpnF                                                                                 1.000000
# Klebsiella pneumoniae KpnE                                                                                 1.000000
# Haemophilus influenzae PBP3 conferring resistance to beta-lactam antibiotics                               1.000000
# FosA8                                                                                                      0.888889
# Escherichia coli GlpT with mutation conferring resistance to fosfomycin                                    0.888889
# leuO                                                                                                       0.666667
# acrB                                                                                                       0.666667
# acrD                                                                                                       0.666667
# emrB                                                                                                       0.555556
# Klebsiella pneumoniae KpnH                                                                                 0.444444
# adeF                                                                                                       0.333333
# CMA-2                                                                                                      0.222222
# Escherichia coli mdfA                                                                                      0.222222
# CSA-2                                                                                                      0.111111
# CSA-1                                                                                                      0.111111
# FosA4                                                                                                      0.111111
# baeR                                                                                                       0.111111
# mdtC                                                                                                       0.111111
# mdtB                                                                                                       0.111111
# dtype: float64
#
# 🔹 Community 13 (Size: 8)
# Members:
#    - Pseudomonas multiresinivorans strain populi
#    - Halomonas sulfidivorans strain MCCC 1A13718
#    - Alloalcanivorax xenomutans strain GOM8
#    - Hahella chejuensis KCTC 2396
#    - Salinicola tamaricis strain F01
#    - Alloalcanivorax dieselolei B5
#    - Billgrantia sulfidoxydans strain MCCC 1A11059
#    - Pseudomonas nitroreducens strain L4
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# Pseudomonas aeruginosa soxR    1.00
# rsmA                           1.00
# adeF                           1.00
# MexB                           0.25
# YajC                           0.25
# dtype: float64
#
# 🔹 Community 14 (Size: 8)
# Members:
#    - Streptomyces nigrescens strain DSM 40276
#    - Streptomyces aurantiacus strain JCM 4677
#    - Streptomyces decoyicus strain NRRL 2666
#    - Streptomyces caniferus strain NBC_00270
#    - Streptomyces europaeiscabiei strain NBC_00515
#    - Streptomyces libani subsp. libani strain DSM 40555
#    - Streptomyces lydicus strain GS93 isolate 23
#    - Streptomyces nojiriensis strain JCM 3382
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# HelR                            1.000
# Streptomyces venezuelae rox     1.000
# Streptomyces lividans otr(A)    0.875
# dtype: float64
#
# 🔹 Community 15 (Size: 7)
# Members:
#    - Shigella dysenteriae strain SWHEFF_49
#    - Escherichia albertii strain BIA_5-2
#    - Escherichia marmotae strain YF8
#    - Escherichia coli O157:H7 str. Sakai DNA
#    - Shigella sonnei strain ATCC 29930
#    - Escherichia coli str. K-12 substr. MG1655
#    - Shigella flexneri 2a str. 301
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# CRP                                                                             1.000000
# ArnT                                                                            1.000000
# Escherichia coli soxS with mutation conferring antibiotic resistance            1.000000
# Klebsiella pneumoniae KpnE                                                      1.000000
# Haemophilus influenzae PBP3 conferring resistance to beta-lactam antibiotics    1.000000
#                                                                                   ...
# oqxA                                                                            0.142857
# qacL                                                                            0.142857
# sul3                                                                            0.142857
# tet(B)                                                                          0.142857
# tetR                                                                            0.142857
# Length: 73, dtype: float64
#
# 🔹 Community 16 (Size: 7)
# Members:
#    - Qiania dongpingensis strain NSJ-38
#    - Vallitalea guaymasensis strain Ra1766G1
#    - Desulfoscipio gibsoniae DSM 7213
#    - Cytobacillus gottheilii strain 1839
#    - Herbinix luporum strain SD1D
#    - Cellulosilyticum lentocellum DSM 5427
#    - Candidatus Contubernalis alkalaceticus strain Z-7904
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# vanG                          1.000000
# vanT gene in vanG cluster     1.000000
# vanW gene in vanI cluster     1.000000
# vanXY gene in vanG cluster    0.714286
# tet(W)                        0.142857
# FosBx1                        0.142857
# ANT(6)-Ia                     0.142857
# vanR gene in vanI cluster     0.142857
# dtype: float64
#
# 🔹 Community 17 (Size: 7)
# Members:
#    - Burkholderia arboris strain PN-1
#    - Burkholderia lata
#    - Burkholderia metallica strain FL-6-5-30-S1-D7
#    - Burkholderia seminalis strain FL-5-4-10-S1-D7
#    - Burkholderia ambifaria AMMD
#    - Burkholderia vietnamiensis LMG 10929
#    - Burkholderia territorii strain RF8-non-BP5
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# amrA    1.000000
# amrB    1.000000
# ceoB    1.000000
# adeF    0.571429
# dtype: float64
#
# 🔹 Community 18 (Size: 6)
# Members:
#    - Burkholderia mayonis strain BDU6
#    - Burkholderia oklahomensis C6786
#    - Burkholderia savannae strain MSMB266
#    - Burkholderia humptydooensis strain MSMB43
#    - Burkholderia pseudomallei strain GTC3P0254T
#    - Burkholderia thailandensis E264
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# Burkholderia pseudomallei Omp38    1.000000
# amrA                               1.000000
# adeF                               1.000000
# amrB                               1.000000
# OXA-42                             0.166667
# OXA-59                             0.166667
# qacJ                               0.166667
# dtype: float64
#
# 🔹 Community 19 (Size: 6)
# Members:
#    - Streptococcus iniae strain YSFST01-82
#    - Streptococcus dysgalactiae strain FDAARGOS_1017
#    - Streptococcus parauberis NCFD 2020
#    - Streptococcus uberis strain NCTC3858
#    - Streptococcus pseudoporcinus strain NCTC13786
#    - Streptococcus canis strain NCTC12191
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# mreA      1.000000
# patA      1.000000
# patB      1.000000
# tet(M)    0.166667
# dtype: float64
#
# 🔹 Community 20 (Size: 6)
# Members:
#    - Pseudomonas toyotomiensis strain SM2
#    - Pseudomonas hydrolytica strain DSWY01
#    - Pseudomonas wenzhouensis strain A20
#    - Ectopseudomonas mendocina S5.2
#    - Pseudomonas sediminis strain B10D7D
#    - Pseudomonas khazarica strain ODT-83
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# PRC-1                          1.000000
# adeF                           1.000000
# rsmA                           1.000000
# Pseudomonas aeruginosa soxR    0.333333
# dtype: float64
#
# 🔹 Community 21 (Size: 6)
# Members:
#    - Mycobacterium shinjukuense strain JCM 14233
#    - Mycobacterium shottsii strain JCM 12657
#    - Mycobacterium pseudoshottsii JCM 15466
#    - Mycobacterium ulcerans subsp. shinshuense strain ATCC 33728
#    - Mycobacterium marinum E11
#    - Mycobacterium basiliense isolate 901379
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# AAC(2')-Ic                                                                                         1.0
# Mycobacterium tuberculosis intrinsic murA conferring resistance to fosfomycin                      1.0
# Mycobacterium tuberculosis ribD with mutation conferring resistance to para-aminosalicylic acid    1.0
# dtype: float64
#
# 🔹 Community 22 (Size: 6)
# Members:
#    - Alteromonas naphthalenivorans
#    - Gallaecimonas kandeliae strain Q10
#    - Oceanimonas pelagia strain NTOU-MSR1
#    - Aeromonas enteropelogenes strain FDAARGOS_1510
#    - Aeromonas rivuli strain 20-VB00005
#    - Gallaecimonas mangrovi strain HK-28
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# Escherichia coli EF-Tu mutants conferring resistance to Pulvomycin    1.000000
# adeF                                                                  1.000000
# rsmA                                                                  1.000000
# TRU-1                                                                 0.333333
# FosA8                                                                 0.166667
# vanT gene in vanG cluster                                             0.166667
# dtype: float64
#
# 🔹 Community 23 (Size: 5)
# Members:
#    - Amycolatopsis aidingensis strain YIM 96748
#    - Amycolatopsis roodepoortensis strain ZEL-1
#    - Amycolatopsis keratiniphila
#    - Actinocatenispora thailandica strain NBRC 105041
#    - Kribbella flavida DSM 17836
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# vanH gene in vanO cluster      1.0
# Streptomyces venezuelae rox    1.0
# vanX gene in vanI cluster      1.0
# vanO                           1.0
# Streptomyces rimosus otr(A)    0.8
# HelR                           0.2
# vanW gene in vanI cluster      0.2
# vanY gene in vanB cluster      0.2
# dtype: float64
#
# 🔹 Community 24 (Size: 5)
# Members:
#    - Aeromonas bestiarum strain YK48
#    - Pseudomonas helvetica strain DGS28
#    - Pseudomonas frederiksbergensis strain ERDD5:01
#    - Pseudomonas sessilinigenes strain CMR12a
#    - Pseudomonas idahonensis strain BIM B-1906
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# ArnT     1.0
# FosA8    1.0
# adeF     1.0
# rsmA     1.0
# TRU-1    0.2
# imiH     0.2
# dtype: float64
#
# 🔹 Community 25 (Size: 5)
# Members:
#    - Paenibacillus dendritiformis strain J27TS7
#    - Bacillus cytotoxicus NVH 391-98
#    - Paenibacillus guangzhouensis strain KCTC 33171
#    - Brevibacillus parabrevis strain B3
#    - Metabacillus sediminilitoris strain DSL-17
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# FosBx1                       1.0
# vanW gene in vanI cluster    1.0
# vanT gene in vanG cluster    1.0
# vanG                         0.2
# BcIII                        0.2
# vanW gene in vanB cluster    0.2
# vanY gene in vanF cluster    0.2
# dtype: float64
#
# 🔹 Community 26 (Size: 5)
# Members:
#    - Bacillus sonorensis strain PMC204
#    - Bacillus haynesii strain P19
#    - Bacillus swezeyi strain EA208
#    - Bacillus paralicheniformis strain Bac84
#    - Bacillus glycinifermentans strain SRCM103574
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# BcIII                        1.0
# FosBx1                       1.0
# bcrA                         1.0
# bcrB                         1.0
# vanT gene in vanG cluster    1.0
# bcrC                         1.0
# ErmD                         0.4
# qacG                         0.2
# dtype: float64
#
# 🔹 Community 27 (Size: 5)
# Members:
#    - Bacillus inaquosorum strain A65.1
#    - Bacillus spizizenii TU-B-10
#    - Bacillus subtilis subsp. subtilis str. 168 complete genome
#    - Bacillus rugosus strain A78.1
#    - Bacillus stercoris strain Mal05
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# Bacillus subtilis mprF       1.0
# BcI                          1.0
# FosBx1                       1.0
# vanT gene in vanG cluster    1.0
# vmlR                         1.0
# mphK                         1.0
# lmrB                         1.0
# ykkD                         1.0
# tmrB                         0.8
# blt                          0.8
# aadK                         0.6
# ykkC                         0.6
# bmr                          0.4
# tet(45)                      0.4
# BSU-1                        0.2
# dtype: float64
#
# 🔹 Community 28 (Size: 5)
# Members:
#    - Rubrobacter tropicus strain SCSIO 52909
#    - Desulforamulus reducens MI-1
#    - Desulfosporosinus orientis DSM 765
#    - Clostridium autoethanogenum DSM 10061
#    - Desulfosporosinus acidiphilus SJ4
#
# Top AMR genes by frequency (count/community size):
# Best_Hit_ARO
# vanW gene in vanI cluster                                                  1.0
# Clostridioides difficile gyrB conferring resistance to fluoroquinolones    0.2
# norC                                                                       0.2
# qacG                                                                       0.2
# vanR gene in vanI cluster                                                  0.2
# dtype: float64
